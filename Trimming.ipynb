# %%
pip install -q tensorflow-io
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-io
# Out:
# Requirement already satisfied: tensorflow-io in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (0.16.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow<2.4.0,>=2.3.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow-io) (2.3.1)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.2.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.13.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.15.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.3.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.1.2)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.18.5)
# Requirement already satisfied: wheel>=0.26 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.35.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.1.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.31.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.23.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (50.3.1.post20201107)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.4.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.6.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.16.1)
#
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (4.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (2.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\imalka\anaconda3\envs\tensorflow\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow<2.4.0,>=2.3.0->tensorflow-io) (3.4.0)

# %%
#Read an Audio File

import tensorflow as tf
import tensorflow_io as tfio

audio = tfio.audio.AudioIOTensor('gs://cloud-samples-tests/speech/brooklyn.flac')

print(audio)
# Out:
# <AudioIOTensor: shape=[28979     1], dtype=<dtype: 'int16'>, rate=16000>

# %%
#Slicing

audio_slice = audio[100:]

# remove last dimension
audio_tensor = tf.squeeze(audio_slice, axis=[-1])

print(audio_tensor)
# Out:
# tf.Tensor([16 39 66 ... 56 81 83], shape=(28879,), dtype=int16)

# %%
from IPython.display import Audio

Audio(audio_tensor.numpy(), rate=audio.rate.numpy())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt


tensor = tf.cast(audio_tensor, tf.float32) / 32768.0

plt.figure()
plt.plot(tensor.numpy())

# %%
#Trim the noise

position = tfio.experimental.audio.trim(tensor, axis=0, epsilon=0.1)
print(position)

start = position[0]
stop = position[1]
print(start, stop)

processed = tensor[start:stop]

plt.figure()
plt.plot(processed.numpy())
# Out:
# tf.Tensor([ 2398 23546], shape=(2,), dtype=int64)
# tf.Tensor(2398, shape=(), dtype=int64) tf.Tensor(23546, shape=(), dtype=int64)

# %%
fade = tfio.experimental.audio.fade(
    processed, fade_in=1000, fade_out=2000, mode="logarithmic")

plt.figure()
plt.plot(fade.numpy())


tfio.experimental.audio.fade(
    input, fade_in, fade_out, mode, name=None
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ec11f5212a17> in <module>
#       7
#       8 tfio.experimental.audio.fade(
# ----> 9     input, fade_in, fade_out, mode, name=None
#      10 )
#
# NameError: name 'fade_in' is not defined

# %%
fade = tfio.experimental.audio.fade(
    processed, fade_in=1000, fade_out=2000, mode="logarithmic")

plt.figure()
plt.plot(fade.numpy())

# %%
position = tfio.experimental.audio.trim(tensor, axis=0, epsilon=0.1)
print(position)

start = position[0]
stop = position[1]
print(start, stop)

processed = tensor[start:stop]

plt.figure()
plt.plot(processed.numpy())
# Out:
# tf.Tensor([ 2398 23546], shape=(2,), dtype=int64)
# tf.Tensor(2398, shape=(), dtype=int64) tf.Tensor(23546, shape=(), dtype=int64)

# %%
fade = tfio.experimental.audio.fade(
    processed, fade_in=1000, fade_out=2000, mode="logarithmic")

plt.figure()
plt.plot(fade.numpy())

# %%
# Convert to spectrogram
spectrogram = tfio.experimental.audio.spectrogram(
    fade, nfft=512, window=512, stride=256)

plt.figure()
plt.imshow(tf.math.log(spectrogram).numpy())

# %%
# Convert to mel-spectrogram
mel_spectrogram = tfio.experimental.audio.melscale(
    spectrogram, rate=16000, mels=128, fmin=0, fmax=8000)


plt.figure()
plt.imshow(tf.math.log(mel_spectrogram).numpy())

# Convert to db scale mel-spectrogram
dbscale_mel_spectrogram = tfio.experimental.audio.dbscale(
    mel_spectrogram, top_db=80)

plt.figure()
plt.imshow(dbscale_mel_spectrogram.numpy())

# %%
# Freq masking
freq_mask = tfio.experimental.audio.freq_mask(dbscale_mel_spectrogram, param=10)

plt.figure()
plt.imshow(freq_mask.numpy())

# %%
# Time masking
time_mask = tfio.experimental.audio.time_mask(dbscale_mel_spectrogram, param=10)

plt.figure()
plt.imshow(time_mask.numpy())
